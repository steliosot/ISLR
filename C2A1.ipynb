# %%
import pandas as pd
import seaborn as sns
import numpy as np
college = pd.read_csv("/Users/Stelios/PyCharmProjects/C2A/College.csv",index_col=0)

# %%
len(college)
college.shape
# Out:
# (777, 18)

# %%
# %matplotlib inline
sns.set(style="ticks", color_codes=True)
sns.pairplot(data=college[college.columns[0:11]])

# %%
sns.boxplot(x=college['Outstate'])

# %%
sns.boxplot(x=college['Outstate'],y=college['Private'])

# %%
Elite=np.repeat('No',len(college))

# %%
Elite[college['Top10perc']>50]
# Out:
# array(['No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No'],
#       dtype='<U2')

# %%
Elite[college['Top10perc']>50]='Yes'
Elite
# Out:
# array(['No', 'No', 'No', 'Ye', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'Ye', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'Ye', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Ye',
#        'No', 'No', 'No', 'No', 'No', 'Ye', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'Ye', 'Ye', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Ye', 'Ye',
#        'No', 'No', 'No', 'Ye', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Ye', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'Ye', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'Ye', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'Ye', 'Ye', 'No', 'Ye', 'No', 'No',
# ...

# %%
college['Elite']=Elite
# Elite = pd.Series(Elite, dtype="category")

# %%
college.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
college['Elite'].describe()
# Out:
# count     777
# unique      2
# top        No
# freq      699
# Name: Elite, dtype: object

# %%
college.groupby(['Elite']).size()
# Out:
# Elite
# No    699
# Ye     78
# dtype: int64

# %%
sns.distplot(college['Outstate']);

# %%
sns.distplot(college['Enroll']);

# %%
sns.lmplot('Outstate','Enroll',data=college, fit_reg=False)

# %%
sns.lmplot('Outstate','Grad.Rate',data=college, fit_reg=False)
